# %%
import pandas as pd
import numpy as np
import geopandas as gpd

# %%
mah_df = gpd.read_file("AI for Safer Roads 2026 - Dataset/ADB_Innovation_Maharashtra.geojson")
thai_df = gpd.read_file("AI for Safer Roads 2026 - Dataset/ADB_Innovation_Thailand.geojson")
hel_df = pd.read_excel("AI for Safer Roads 2026 - Dataset/Archive/Road_Safety_Performance_Indicators_(Helmet_Wearing_results)_(adb_dashboard_data_v02).xlsx")
mah_df_arch = gpd.read_file("AI for Safer Roads 2026 - Dataset/Archive/Road_Safety_Performance_Indicators__Maharashtra_(Feature).gpkg")
thai_df_arch = gpd.read_file("AI for Safer Roads 2026 - Dataset/Archive/Road_Safety_Performance_Indicators__Thailand_(Feature).gpkg")
# Out:
# c:\Users\simeo\Desktop\Random\codingProjects\env\lib\site-packages\pyogrio\geopandas.py:382: UserWarning: More than one layer found in 'Road_Safety_Performance_Indicators__Maharashtra_(Feature).gpkg': 'OvertureNetwork_wResults' (default), 'Boundaries_4helmet'. Specify layer parameter to avoid this warning.
#   result = read_func(
# c:\Users\simeo\Desktop\Random\codingProjects\env\lib\site-packages\pyogrio\geopandas.py:382: UserWarning: More than one layer found in 'Road_Safety_Performance_Indicators__Thailand_(Feature).gpkg': 'ADB_Results_D4' (default), 'Thailand_Province_Boundaries', 'Analysis', 'AnalysisAggregated', 'AggregatedPercentiles'. Specify layer parameter to avoid this warning.
#   result = read_func(

# %%
print(f"Columns in maharashtra geojson file: \n{mah_df.columns}")
print(f"\nColumns in thailand geojson file: \n{thai_df.columns}")
print(f"\nColumns in helmet wearing results file in archive: \n{hel_df.columns}")
print(f"\nColumns in maharashtra geopackage file in archive: \n{mah_df_arch.columns}")
print(f"\nColumns in thailand geopackage file in archive: \n{thai_df_arch.columns}")
# Out:
# Columns in maharashtra geojson file:
# Index(['OBJECTID', 'DISSOLVE_ID', 'class', 'subtype', 'names_primary',
#        'UrbanPC', 'SampleSize_avg', 'RoadLength', 'WeightedSample', 'Percent_',
#        'Percentile', 'SpeedLimit', 'RoadClass', 'LandUse', 'NumberOverLimit',
#        'MedianSpeed', 'F85thPercentileSpeed', 'Pass', 'ExcludeFromSpeedSPI',
#        'PercentileBand', 'RankedPercentile', 'Sample_Size_Total',
#        'SpeedLimitFloor', 'PercentOverLimit', 'AnalysisStatus',
#        'StreetImageLink', 'Shape_Length', 'geometry'],
#       dtype='object')
#
# Columns in thailand geojson file:
# Index(['OBJECTID', 'english_ro', 'OvertureID', 'SampleSize_avg', 'RoadLength',
#        'WeightedSample', 'Percent_', 'Percentile', 'SpeedLimit', 'RoadClass',
#        'NumberOverLimit', 'MedianSpeed', 'F85thPercentileSpeed', 'ForAnalysis',
#        'ProvinceID', 'SpeedLimitFloor', 'PercentOverLimit', 'InvPercentile',
# ...

# %%
print(f"Columns in maharashtra geojson file: \n{mah_df.info()}")
print(f"\nColumns in thailand geojson file: \n{thai_df.info()}")
print(f"\nColumns in helmet wearing results file in archive: \n{hel_df.info()}")
print(f"\nColumns in maharashtra geopackage file in archive: \n{mah_df_arch.info()}")
print(f"\nColumns in thailand geopackage file in archive: \n{thai_df_arch.info()}")
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 14082 entries, 0 to 14081
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OBJECTID              14082 non-null  int32
#  1   DISSOLVE_ID           14082 non-null  object
#  2   class                 14082 non-null  object
#  3   subtype               14082 non-null  object
#  4   names_primary         4014 non-null   object
#  5   UrbanPC               4010 non-null   float64
#  6   SampleSize_avg        4010 non-null   float64
#  7   RoadLength            4010 non-null   float64
#  8   WeightedSample        4010 non-null   float64
#  9   Percent_              4010 non-null   float64
#  10  Percentile            4010 non-null   float64
#  11  SpeedLimit            3577 non-null   object
#  12  RoadClass             4010 non-null   object
#  13  LandUse               4010 non-null   object
# ...
